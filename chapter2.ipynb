# %%
from importlib_metadata import version
print("torch version", version("torch"))
print("tiktoken vesrion", version("tiktoken"))
# Out:
# torch version 2.11.0+cpu
# tiktoken vesrion 0.14.0

# %%
import os
import requests

if not os.path.exists("the-verdict.txt"):
    url = (
        "https://raw.githubusercontent.com/rasbt/"
        "LLMs-from-scratch/main/ch02/01_main-chapter-code/"
        "the-verdict.txt"
    )
    file_path = "the-verdict.txt"

    response = requests.get(url, timeout=30)
    response.raise_for_status()
    with open(file_path, "wb") as f:
        f.write(response.content)


# The book originally used the following code below
# However, urllib uses older protocol settings that
# can cause problems for some readers using a VPN.
# The `requests` version above is more robust
# in that regard.

"""
import os
import urllib.request

if not os.path.exists("the-verdict.txt"):
    url = ("https://raw.githubusercontent.com/rasbt/"
           "LLMs-from-scratch/main/ch02/01_main-chapter-code/"
           "the-verdict.txt")
    file_path = "the-verdict.txt"
    urllib.request.urlretrieve(url, file_path)
"""
# Out:
# '\nimport os\nimport urllib.request\n\nif not os.path.exists("the-verdict.txt"):\n    url = ("https://raw.githubusercontent.com/rasbt/"\n           "LLMs-from-scratch/main/ch02/01_main-chapter-code/"\n           "the-verdict.txt")\n    file_path = "the-verdict.txt"\n    urllib.request.urlretrieve(url, file_path)\n'

# %%
with open("the-verdict.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()
print("Total number of charcters:", len(raw_text))
print(raw_text[:55])
# Out:
# Total number of charcters: 20479
# I HAD always thought Jack Gisburn rather a cheap genius

# %%
import re
text = "here we are testing, the spliting."
result = re.split(r'(\s)',text)
print(result)
# Out:
# ['here', ' ', 'we', ' ', 'are', ' ', 'testing,', ' ', 'the', ' ', 'spliting.']

# %%
result=re.split(r'([,.]|\s)', text)
print(result)
# Out:
# ['here', ' ', 'we', ' ', 'are', ' ', 'testing', ',', '', ' ', 'the', ' ', 'spliting', '.', '']

# %%
# strip whitespace from each item and the filter out any empty strings
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['here', 'we', 'are', 'testing', ',', 'the', 'spliting', '.']

# %%
text = "here we are testing the spliting."
result = re.split(r'([,.:;?_!"()\']|--|\s)', text)
result = [item.strip() for item in result if item.strip()]
print(result)
# Out:
# ['here', 'we', 'are', 'testing', 'the', 'spliting', '.']

# %%
preprocessed = re.split(r'([,.:;?_!"()\']|--|\s)',raw_text)
preprocessed = [item.strip() for item in preprocessed if item.strip()]
print(preprocessed[:50])
# Out:
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', '--', 'though', 'a', 'good', 'fellow', 'enough', '--', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', ',', 'in', 'the', 'height', 'of', 'his', 'glory', ',', 'he', 'had', 'dropped', 'his', 'painting', ',', 'married', 'a', 'rich', 'widow', ',', 'and', 'established', 'himself']

# %%
print(len(preprocessed))
# Out:
# 4690

# %% [markdown]
# ## converting the tokens into IDs
